# %%
import googleapiclient.discovery
import pandas as pd
from dateutil import parser
import isodate
from IPython.display import JSON

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud

# %%
api_key = 'AIzaSyALKRBtb_1ObsO8ECnIEU-rBQfPa2qZbaI'

# %%
channel_ids = ['UCBwmMxybNva6P_5VmxjzwqA',
               'UC8iaIXQVsv9STE6xGvG0u0w'
                     #more ids here
                    ]

# %%
api_service_name = "youtube"
api_version = "v3"
    

# Get credentials and create an API client
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = api_key)

# %%
def get_channel_stats(youtube, channel_usernames):
    
    all_data = []

    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    for item in response['items']:
        data = {'channelName' : item['snippet']['title'],
                'subscribers' : item['statistics']['subscriberCount'],
                'views' : item['statistics']['viewCount'],
                'totalViews' : item['statistics']['videoCount'],
                'playlistId' : item['contentDetails']['relatedPlaylists']['uploads']
                
        }  
        all_data.append(data)
        
    return pd.DataFrame(all_data)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#     channelName subscribers      views totalViews                playlistId
# 0  Apna College     4410000  675117794        775  UUBwmMxybNva6P_5VmxjzwqA

# %%
playlist_id = "UUBwmMxybNva6P_5VmxjzwqA"

def get_video_ids(youtube,playlistId):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults = 50
        )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    
    while next_page_token is not None:
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults = 50,
            pageToken = next_page_token
        )
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube,playlist_id)

# %%
len(video_ids)
# Out:
# 775

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#         video_id  channelTitle  \
# 0    JIbfzmt2LuY  Apna College
# 1    QaU6gEtOwyE  Apna College
# 2    lzuiuRgwwrc  Apna College
# 3    fGQckyRlAOY  Apna College
# 4    Holv98J2eDM  Apna College
# ..           ...           ...
# 770  k2oGoqxRLaw  Apna College
# 771  7rtvYQEAbIo  Apna College
# 772  zGJ5BlbKfLM  Apna College
# 773  1VfqlKtVF7U  Apna College
# 774  Y8Lk3Gi-ugo  Apna College
#
#                                                  title  \
# 0                  How to learn Data Science? In Short
# 1            Roadmap to Web Development | for Students
# 2    How to create a Great LinkedIn Profile in 2023...
# 3    JavaScript Coding Interview Question | @ApnaCo...
# 4              Be the Top 1% Coder | How to Stand Out?
# ..                                                 ...
# 770  Watch this before buying Laptop | Best Budget ...
# 771  IAS at 23 | How to study for UPSC CSE during C...
# 772  Is VIT Vellore Good? | All about VIT Vellore |...
# 773     IIT DELHI College Review | All about IIT Delhi
# 774  India's Top 70 Engineering Colleges | College ...
#
#                                            description  \
# 0                                              #shorts
# 1                                              #shorts
# 2    Hi, if you want to learn Complete Full Stack D...
# 3              #coding #interview #javascript\n#shorts
# 4    Hi, if you want to learn Complete Full Stack D...
# ..                                                 ...
# 770  Are you worried about placements/internships? ...
# 771  0:00 Intro \n1:27 School & Colleg Life\n8:29 M...
# 772  Are you worried about placements/internships? ...
# 773  Are you worried about placements/internships? ...
# 774  Are you worried about placements/internships? ...
#
#                                                   tags           publishedAt  \
# 0    [C++, C++ coding, C++ full course, C++ placeme...  2023-10-19T15:41:19Z
# 1    [C++, C++ coding, C++ full course, C++ placeme...  2023-10-17T14:20:06Z
# 2    [C++, C++ coding, C++ full course, C++ placeme...  2023-10-16T17:39:56Z
# 3    [C++, C++ coding, C++ full course, C++ placeme...  2023-10-12T13:33:29Z
# 4    [C++, C++ coding, C++ full course, C++ placeme...  2023-10-06T14:37:06Z
# ..                                                 ...                   ...
# 770  [laptops, college students, students for colle...  2020-08-14T18:07:44Z
# 771  [upsc, how to study for upsc, ias exam, indian...  2020-08-11T14:41:30Z
# 772  [VIT, VIT Vellore, Vellore Institute of Techno...  2020-08-07T20:14:25Z
# 773  [IIT DELHI, IIT DELHI COLLEGE, top engineering...  2020-08-06T14:32:10Z
# 774  [college, college review, top engineering coll...  2020-08-06T14:04:23Z
#
#     viewCount likeCount favouriteCount commentCount  duration definition  \
# 0       45618      5286           None           60     PT47S         hd
# 1       69960      9895           None           87     PT59S         hd
# 2      135361      7832           None          292   PT19M9S         hd
# 3      107530     12135           None          150     PT53S         hd
# 4      253437     14118           None          696   PT9M35S         hd
# ..        ...       ...            ...          ...       ...        ...
# 770   4243266    146794           None         9525   PT22M1S         hd
# 771    261770     14811           None         1320  PT30M55S         hd
# 772   1236395     33915           None         5827  PT26M16S         hd
# 773   1232152     40549           None         3873  PT22M23S         hd
# 774   1631283     58717           None         5169  PT19M46S         hd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 770   false
# 771   false
# 772   false
# 773   false
# 774   false
#
# [775 rows x 13 columns]

# %%
def get_comments_in_videos(youtube, video_ids):
    all_comments = []
    
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %%
comments_df = get_comments_in_videos(youtube, video_ids)

# %%
comments_df
# Out:
#         video_id                                           comments
# 0    JIbfzmt2LuY  [Phyton full learning tutorial for non IT peop...
# 1    QaU6gEtOwyE  [English 🤬🤬, From that day I am going start my...
# 2    lzuiuRgwwrc  [Your videos are worth their weight in gold, H...
# 3    fGQckyRlAOY  [Didi please JavaScript one shot video, 4, 4, ...
# 4    Holv98J2eDM  [You make learning easy, I am 11 years old and...
# ..           ...                                                ...
# 770  k2oGoqxRLaw  [i have a hp 255 GB is it good for coding, 60k...
# 771  7rtvYQEAbIo  [All the important topics timeline of the ProI...
# 772  zGJ5BlbKfLM  [Many students of VIT VELLORE 2023 mechanical ...
# 773  1VfqlKtVF7U  [thanks for valuable information 😊😊, is there ...
# 774  Y8Lk3Gi-ugo  [cant even see vnit nagpur even when its one o...
#
# [775 rows x 2 columns]

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
numeric_cols  = ['viewCount','likeCount','favouriteCount','commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric,errors = 'coerce', axis = 1)

# %%
video_df['publishedAt'] =  video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs','duration']]
# Out:
#      durationSecs  duration
# 0            47.0     PT47S
# 1            59.0     PT59S
# 2          1149.0   PT19M9S
# 3            53.0     PT53S
# 4           575.0   PT9M35S
# ..            ...       ...
# 770        1321.0   PT22M1S
# 771        1855.0  PT30M55S
# 772        1576.0  PT26M16S
# 773        1343.0  PT22M23S
# 774        1186.0  PT19M46S
#
# [775 rows x 2 columns]

# %%
video_df['tagsCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#         video_id  channelTitle  \
# 0    JIbfzmt2LuY  Apna College
# 1    QaU6gEtOwyE  Apna College
# 2    lzuiuRgwwrc  Apna College
# 3    fGQckyRlAOY  Apna College
# 4    Holv98J2eDM  Apna College
# ..           ...           ...
# 770  k2oGoqxRLaw  Apna College
# 771  7rtvYQEAbIo  Apna College
# 772  zGJ5BlbKfLM  Apna College
# 773  1VfqlKtVF7U  Apna College
# 774  Y8Lk3Gi-ugo  Apna College
#
#                                                  title  \
# 0                  How to learn Data Science? In Short
# 1            Roadmap to Web Development | for Students
# 2    How to create a Great LinkedIn Profile in 2023...
# 3    JavaScript Coding Interview Question | @ApnaCo...
# 4              Be the Top 1% Coder | How to Stand Out?
# ..                                                 ...
# 770  Watch this before buying Laptop | Best Budget ...
# 771  IAS at 23 | How to study for UPSC CSE during C...
# 772  Is VIT Vellore Good? | All about VIT Vellore |...
# 773     IIT DELHI College Review | All about IIT Delhi
# 774  India's Top 70 Engineering Colleges | College ...
#
#                                            description  \
# 0                                              #shorts
# 1                                              #shorts
# 2    Hi, if you want to learn Complete Full Stack D...
# 3              #coding #interview #javascript\n#shorts
# 4    Hi, if you want to learn Complete Full Stack D...
# ..                                                 ...
# 770  Are you worried about placements/internships? ...
# 771  0:00 Intro \n1:27 School & Colleg Life\n8:29 M...
# 772  Are you worried about placements/internships? ...
# 773  Are you worried about placements/internships? ...
# 774  Are you worried about placements/internships? ...
#
#                                                   tags  \
# 0    [C++, C++ coding, C++ full course, C++ placeme...
# 1    [C++, C++ coding, C++ full course, C++ placeme...
# 2    [C++, C++ coding, C++ full course, C++ placeme...
# 3    [C++, C++ coding, C++ full course, C++ placeme...
# 4    [C++, C++ coding, C++ full course, C++ placeme...
# ..                                                 ...
# 770  [laptops, college students, students for colle...
# 771  [upsc, how to study for upsc, ias exam, indian...
# 772  [VIT, VIT Vellore, Vellore Institute of Techno...
# 773  [IIT DELHI, IIT DELHI COLLEGE, top engineering...
# 774  [college, college review, top engineering coll...
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2023-10-19 15:41:19+00:00    45618.0     5286.0             NaN
# 1   2023-10-17 14:20:06+00:00    69960.0     9895.0             NaN
# 2   2023-10-16 17:39:56+00:00   135361.0     7832.0             NaN
# 3   2023-10-12 13:33:29+00:00   107530.0    12135.0             NaN
# 4   2023-10-06 14:37:06+00:00   253437.0    14118.0             NaN
# ..                        ...        ...        ...             ...
# 770 2020-08-14 18:07:44+00:00  4243266.0   146794.0             NaN
# 771 2020-08-11 14:41:30+00:00   261770.0    14811.0             NaN
# 772 2020-08-07 20:14:25+00:00  1236395.0    33915.0             NaN
# 773 2020-08-06 14:32:10+00:00  1232152.0    40549.0             NaN
# 774 2020-08-06 14:04:23+00:00  1631283.0    58717.0             NaN
#
#      commentCount  duration definition caption pushblishDayName  durationSecs  \
# 0            60.0     PT47S         hd   false         Thursday          47.0
# 1            87.0     PT59S         hd   false          Tuesday          59.0
# 2           292.0   PT19M9S         hd   false           Monday        1149.0
# 3           150.0     PT53S         hd   false         Thursday          53.0
# 4           696.0   PT9M35S         hd   false           Friday         575.0
# ..            ...       ...        ...     ...              ...           ...
# 770        9525.0   PT22M1S         hd   false           Friday        1321.0
# 771        1320.0  PT30M55S         hd   false          Tuesday        1855.0
# 772        5827.0  PT26M16S         hd   false           Friday        1576.0
# 773        3873.0  PT22M23S         hd   false         Thursday        1343.0
# 774        5169.0  PT19M46S         hd   false         Thursday        1186.0
#
#      tagsCount
# 0           14
# 1           14
# 2           14
# 3           14
# 4           14
# ..         ...
# 770          8
# 771         12
# 772         12
# 773          9
# 774          8
#
# [775 rows x 16 columns]

# %% [markdown]
# # EDA

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount',ascending = False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.0f}'.format(x/1000)+'K'))

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount',ascending = True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.0f}'.format(x/1000)+'K'))

# %%
sns.violinplot(x = video_df['channelTitle'], y = video_df['viewCount'])
# Out:
# <Axes: xlabel='channelTitle', ylabel='viewCount'>

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <Axes: xlabel='likeCount', ylabel='viewCount'>

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins = 30)
# Out:
# <Axes: xlabel='durationSecs', ylabel='Count'>

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %%
day_df = pd.DataFrame(video_df['pushblishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=0)
