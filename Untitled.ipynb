# %%
import googleapiclient.discovery
import pandas as pd
from dateutil import parser
import isodate
from IPython.display import JSON

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud

# %%
api_key = 'AIzaSyALKRBtb_1ObsO8ECnIEU-rBQfPa2qZbaI'

# %%
channel_ids = ['UCBwmMxybNva6P_5VmxjzwqA',
               'UC8iaIXQVsv9STE6xGvG0u0w',
               'UCI4B8xu9phHmgQXmECLCSjw',
               'UC5jlhhowFYlOr0klxWglpGQ'
                     #more ids here
                    ]

# %%
api_service_name = "youtube"
api_version = "v3"
    

# Get credentials and create an API client
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = api_key)

# %%
def get_channel_stats(youtube, channel_usernames):
    
    all_data = []

    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    for item in response['items']:
        data = {'channelName' : item['snippet']['title'],
                'subscribers' : item['statistics']['subscriberCount'],
                'views' : item['statistics']['viewCount'],
                'totalViews' : item['statistics']['videoCount'],
                'playlistId' : item['contentDetails']['relatedPlaylists']['uploads']
                
        }  
        all_data.append(data)
        
    return pd.DataFrame(all_data)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#          channelName subscribers      views totalViews  \
# 0            Gyanshu         425      23132         19
# 1       Apna College     4410000  675117794        775
# 2          Lashcurry       13200     575889         31
# 3  Trades With Ishan           4        103          7
#
#                  playlistId
# 0  UUI4B8xu9phHmgQXmECLCSjw
# 1  UUBwmMxybNva6P_5VmxjzwqA
# 2  UU8iaIXQVsv9STE6xGvG0u0w
# 3  UU5jlhhowFYlOr0klxWglpGQ

# %%
playlist_id = "UU5jlhhowFYlOr0klxWglpGQ"

def get_video_ids(youtube,playlistId):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults = 50
        )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    
    while next_page_token is not None:
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults = 50,
            pageToken = next_page_token
        )
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube,playlist_id)

# %%
len(video_ids)
# Out:
# 7

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#       video_id       channelTitle  \
# 0  gqJUmFB3QjE  Trades With Ishan
# 1  T0YeTzdg8Nk  Trades With Ishan
# 2  7saVYtI6rsk  Trades With Ishan
# 3  NBHrFjVUq_Y  Trades With Ishan
# 4  nrATaNn4xYU  Trades With Ishan
# 5  pNqaC1_8JpE  Trades With Ishan
# 6  EyAy2G1-_3k  Trades With Ishan
#
#                                                title  \
# 0       TWI 17-10-23: RETAIL SALES NEWS XAU USD 🙀🙀🙀🙀
# 1  TWI 12 October 2023  One good trade can cover ...
# 2               TWI 7th October : Where have i BEEN!
# 3                24 AUG 2023 gold long (*SL HIT tho)
# 4                 aug-23-2023 TRADES TAKEN #GOLDPUMP
# 5                         Toy s4 Nights and Weeknds!
# 6                                What da dawg doin!!
#
#                                          description  \
# 0                                  x.com/adityaishxn
# 1                                         Well damn.
# 2                        Maintain a trading JOURNAL.
# 3  Things learnt today- Wait for more confirmatio...
# 4              SO GLAD I POSTED LOL\n\n\naug-23-2023
# 5                        Structure of the Videos lol
# 6  To newer beginnings, all the best to all. Hopi...
#
#                                                 tags           publishedAt  \
# 0                                               None  2023-10-17T12:51:04Z
# 1  [trading, day trading, tradingview, live tradi...  2023-10-12T18:12:36Z
# 2                                               None  2023-10-07T15:51:37Z
# 3  [trading, day trading, tradingview, trading bo...  2023-08-24T16:09:59Z
# 4  [trading, live trading, forex trading, live da...  2023-08-23T16:17:36Z
# 5                                               None  2023-08-21T16:26:53Z
# 6  [#buildspace, #nightsandweekends, #trading #, ...  2023-08-13T19:35:27Z
#
#   viewCount likeCount favouriteCount commentCount duration definition caption
# 0         6         0           None            0  PT1M13S         hd   false
# 1         4         0           None            0  PT5M12S         hd   false
# 2        16         2           None            2  PT10M1S         hd   false
# 3         8         3           None            0  PT2M46S         hd   false
# 4         6         1           None            0  PT2M21S         hd   false
# 5         9         2           None            0  PT2M24S         hd   false
# 6        54         6           None            0    PT22S         hd   false

# %%
def get_comments_in_videos(youtube, video_ids):
    all_comments = []
    
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %%
comments_df = get_comments_in_videos(youtube, video_ids)

# %%
comments_df
# Out:
#       video_id      comments
# 0  gqJUmFB3QjE            []
# 1  T0YeTzdg8Nk            []
# 2  7saVYtI6rsk  [keep doing]
# 3  NBHrFjVUq_Y            []
# 4  nrATaNn4xYU            []
# 5  pNqaC1_8JpE            []
# 6  EyAy2G1-_3k            []

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
numeric_cols  = ['viewCount','likeCount','favouriteCount','commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric,errors = 'coerce', axis = 1)

# %%
video_df['publishedAt'] =  video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs','duration']]
# Out:
#    durationSecs duration
# 0          73.0  PT1M13S
# 1         312.0  PT5M12S
# 2         601.0  PT10M1S
# 3         166.0  PT2M46S
# 4         141.0  PT2M21S
# 5         144.0  PT2M24S
# 6          22.0    PT22S

# %%
video_df['tagsCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#       video_id       channelTitle  \
# 0  gqJUmFB3QjE  Trades With Ishan
# 1  T0YeTzdg8Nk  Trades With Ishan
# 2  7saVYtI6rsk  Trades With Ishan
# 3  NBHrFjVUq_Y  Trades With Ishan
# 4  nrATaNn4xYU  Trades With Ishan
# 5  pNqaC1_8JpE  Trades With Ishan
# 6  EyAy2G1-_3k  Trades With Ishan
#
#                                                title  \
# 0       TWI 17-10-23: RETAIL SALES NEWS XAU USD 🙀🙀🙀🙀
# 1  TWI 12 October 2023  One good trade can cover ...
# 2               TWI 7th October : Where have i BEEN!
# 3                24 AUG 2023 gold long (*SL HIT tho)
# 4                 aug-23-2023 TRADES TAKEN #GOLDPUMP
# 5                         Toy s4 Nights and Weeknds!
# 6                                What da dawg doin!!
#
#                                          description  \
# 0                                  x.com/adityaishxn
# 1                                         Well damn.
# 2                        Maintain a trading JOURNAL.
# 3  Things learnt today- Wait for more confirmatio...
# 4              SO GLAD I POSTED LOL\n\n\naug-23-2023
# 5                        Structure of the Videos lol
# 6  To newer beginnings, all the best to all. Hopi...
#
#                                                 tags  \
# 0                                               None
# 1  [trading, day trading, tradingview, live tradi...
# 2                                               None
# 3  [trading, day trading, tradingview, trading bo...
# 4  [trading, live trading, forex trading, live da...
# 5                                               None
# 6  [#buildspace, #nightsandweekends, #trading #, ...
#
#                 publishedAt  viewCount  likeCount  favouriteCount  \
# 0 2023-10-17 12:51:04+00:00        6.0        0.0             NaN
# 1 2023-10-12 18:12:36+00:00        4.0        0.0             NaN
# 2 2023-10-07 15:51:37+00:00       16.0        2.0             NaN
# 3 2023-08-24 16:09:59+00:00        8.0        3.0             NaN
# 4 2023-08-23 16:17:36+00:00        6.0        1.0             NaN
# 5 2023-08-21 16:26:53+00:00        9.0        2.0             NaN
# 6 2023-08-13 19:35:27+00:00       54.0        6.0             NaN
#
#    commentCount duration definition caption pushblishDayName  durationSecs  \
# 0           0.0  PT1M13S         hd   false          Tuesday          73.0
# 1           0.0  PT5M12S         hd   false         Thursday         312.0
# 2           2.0  PT10M1S         hd   false         Saturday         601.0
# 3           0.0  PT2M46S         hd   false         Thursday         166.0
# 4           0.0  PT2M21S         hd   false        Wednesday         141.0
# 5           0.0  PT2M24S         hd   false           Monday         144.0
# 6           0.0    PT22S         hd   false           Sunday          22.0
#
#    tagsCount
# 0          0
# 1         26
# 2          0
# 3         29
# 4         22
# 5          0
# 6         26

# %% [markdown]
# # EDA

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount',ascending = False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.0f}'.format(x/1000)+'K'))

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount',ascending = True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.0f}'.format(x/1000)+'K'))

# %%
sns.violinplot(x = video_df['channelTitle'], y = video_df['viewCount'])
# Out:
# <Axes: xlabel='channelTitle', ylabel='viewCount'>

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <Axes: xlabel='likeCount', ylabel='viewCount'>

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins = 30)
# Out:
# <Axes: xlabel='durationSecs', ylabel='Count'>

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %%
day_df = pd.DataFrame(video_df['pushblishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=0)
